# %%
import cv2,os
data_path='/kaggle/input/koa-1500/MedicalExpert-I'
categories=os.listdir(data_path)
labels=[i for i in range(len(categories))]

label_dict=dict(zip(categories,labels)) #empty dictionary
print(label_dict)
print(categories)
print(labels)
# Out:
# {'1Doubtful': 0, '3Moderate': 1, '4Severe': 2, '2Mild': 3, '0Normal': 4}
# ['1Doubtful', '3Moderate', '4Severe', '2Mild', '0Normal']
# [0, 1, 2, 3, 4]

# %%
img_size=256
data=[]
label=[]
for category in categories:
    folder_path=os.path.join(data_path,category)
    img_names=os.listdir(folder_path)
        
    for img_name in img_names:
        img_path=os.path.join(folder_path,img_name)
        img=cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)  
            resized=cv2.resize(gray,(img_size,img_size))
            #resizing the image  into 256 x 256, since we need a fixed common size for all the images in the dataset
            data.append(resized)
            label.append(label_dict[category])
            #appending the image and the label(categorized) into the list (dataset)
        except Exception as e:
            print('Exception:',e)
            #if any exception rasied, the exception will be printed here. And pass to the next image

# %%
import numpy as np
data=np.array(data)/255.0
data=np.reshape(data,(data.shape[0],img_size,img_size,1))
label=np.array(label)
from keras.utils import np_utils
new_label=np_utils.to_categorical(label)

from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
model=Sequential()

model.add(Conv2D(128,(3,3),input_shape=data.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The first CNN layer followed by Relu and MaxPooling layers

model.add(Conv2D(64,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The second convolution layer followed by Relu and MaxPooling layers

model.add(Conv2D(32,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#The thrid convolution layer followed by Relu and MaxPooling layers

model.add(Flatten())
#Flatten layer to stack the output convolutions from 3rd convolution layer
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
#Dense layer of 128 neurons

model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
#Dense layer of 64 neurons

model.add(Dense(5,activation='softmax'))
#The Final layer with two outputs for two categories

model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 128)     1280
#
#  activation (Activation)     (None, 254, 254, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 128)    0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      73792
#
#  activation_1 (Activation)   (None, 125, 125, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 32)        18464
#
#  activation_2 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dropout (Dropout)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 3,788,645
# Trainable params: 3,788,645
# Non-trainable params: 0
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(data,new_label,test_size=0.1)

import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
for i in range(20):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.squeeze(x_test[i]))
    plt.xlabel(categories[np.argmax(y_test[i])])
plt.show()

# %%
history=model.fit(x_train,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 20s 158ms/step - loss: 1.5448 - accuracy: 0.3131 - val_loss: 1.5490 - val_accuracy: 0.2862
# Epoch 2/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.4765 - accuracy: 0.3502 - val_loss: 1.5400 - val_accuracy: 0.2727
# Epoch 3/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.4467 - accuracy: 0.3704 - val_loss: 1.4959 - val_accuracy: 0.3401
# Epoch 4/100
# 38/38 [==============================] - 4s 118ms/step - loss: 1.4219 - accuracy: 0.3872 - val_loss: 1.4949 - val_accuracy: 0.3569
# Epoch 5/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.3872 - accuracy: 0.4141 - val_loss: 1.4429 - val_accuracy: 0.3636
# Epoch 6/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.3523 - accuracy: 0.4285 - val_loss: 1.4778 - val_accuracy: 0.3502
# Epoch 7/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.3331 - accuracy: 0.4200 - val_loss: 1.5004 - val_accuracy: 0.3535
# Epoch 8/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.3034 - accuracy: 0.4285 - val_loss: 1.4737 - val_accuracy: 0.3603
# Epoch 9/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.3249 - accuracy: 0.4234 - val_loss: 1.4004 - val_accuracy: 0.4209
# Epoch 10/100
# 38/38 [==============================] - 5s 119ms/step - loss: 1.2464 - accuracy: 0.4596 - val_loss: 1.3624 - val_accuracy: 0.4276
# Epoch 11/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.1972 - accuracy: 0.4882 - val_loss: 1.3533 - val_accuracy: 0.4242
# Epoch 12/100
# 38/38 [==============================] - 5s 122ms/step - loss: 1.1463 - accuracy: 0.5202 - val_loss: 1.4851 - val_accuracy: 0.4377
# Epoch 13/100
# 38/38 [==============================] - 5s 120ms/step - loss: 1.1370 - accuracy: 0.5295 - val_loss: 1.4428 - val_accuracy: 0.4141
# Epoch 14/100
# 38/38 [==============================] - 5s 122ms/step - loss: 1.0811 - accuracy: 0.5480 - val_loss: 1.3673 - val_accuracy: 0.4579
# Epoch 15/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.9858 - accuracy: 0.5783 - val_loss: 1.3763 - val_accuracy: 0.4882
# Epoch 16/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.9595 - accuracy: 0.6170 - val_loss: 1.3731 - val_accuracy: 0.4815
# Epoch 17/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.8219 - accuracy: 0.6490 - val_loss: 1.3751 - val_accuracy: 0.4916
# Epoch 18/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.7766 - accuracy: 0.6793 - val_loss: 1.4998 - val_accuracy: 0.4882
# Epoch 19/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.7425 - accuracy: 0.7037 - val_loss: 1.7788 - val_accuracy: 0.4613
# Epoch 20/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.5728 - accuracy: 0.7753 - val_loss: 1.5550 - val_accuracy: 0.5219
# Epoch 21/100
# 38/38 [==============================] - 5s 126ms/step - loss: 0.4920 - accuracy: 0.8140 - val_loss: 1.6043 - val_accuracy: 0.5286
# Epoch 22/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.4255 - accuracy: 0.8325 - val_loss: 1.8631 - val_accuracy: 0.4747
# Epoch 23/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.4486 - accuracy: 0.8291 - val_loss: 1.6923 - val_accuracy: 0.5118
# Epoch 24/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2776 - accuracy: 0.8923 - val_loss: 1.8382 - val_accuracy: 0.5589
# Epoch 25/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.2569 - accuracy: 0.9057 - val_loss: 2.1722 - val_accuracy: 0.5320
# Epoch 26/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.2194 - accuracy: 0.9217 - val_loss: 2.0606 - val_accuracy: 0.5791
# Epoch 27/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1689 - accuracy: 0.9411 - val_loss: 2.3164 - val_accuracy: 0.5657
# Epoch 28/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1485 - accuracy: 0.9453 - val_loss: 2.1877 - val_accuracy: 0.5522
# Epoch 29/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1573 - accuracy: 0.9470 - val_loss: 2.5718 - val_accuracy: 0.5556
# Epoch 30/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1076 - accuracy: 0.9680 - val_loss: 2.3923 - val_accuracy: 0.5488
# Epoch 31/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1050 - accuracy: 0.9680 - val_loss: 2.7735 - val_accuracy: 0.5488
# Epoch 32/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0900 - accuracy: 0.9739 - val_loss: 2.4956 - val_accuracy: 0.5387
# Epoch 33/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1115 - accuracy: 0.9655 - val_loss: 2.4704 - val_accuracy: 0.5387
# Epoch 34/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1052 - accuracy: 0.9672 - val_loss: 2.7091 - val_accuracy: 0.5354
# Epoch 35/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0741 - accuracy: 0.9790 - val_loss: 2.9473 - val_accuracy: 0.5421
# Epoch 36/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1028 - accuracy: 0.9672 - val_loss: 2.7540 - val_accuracy: 0.5320
# Epoch 37/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1027 - accuracy: 0.9663 - val_loss: 2.6875 - val_accuracy: 0.5488
# Epoch 38/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0678 - accuracy: 0.9764 - val_loss: 2.9007 - val_accuracy: 0.5589
# Epoch 39/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0817 - accuracy: 0.9731 - val_loss: 2.7699 - val_accuracy: 0.5488
# Epoch 40/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0706 - accuracy: 0.9773 - val_loss: 3.0943 - val_accuracy: 0.5421
# Epoch 41/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.1326 - accuracy: 0.9579 - val_loss: 2.8204 - val_accuracy: 0.5185
# Epoch 42/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0705 - accuracy: 0.9756 - val_loss: 3.3506 - val_accuracy: 0.4983
# Epoch 43/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0643 - accuracy: 0.9781 - val_loss: 2.8864 - val_accuracy: 0.5286
# Epoch 44/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0630 - accuracy: 0.9781 - val_loss: 3.0263 - val_accuracy: 0.5185
# Epoch 45/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0909 - accuracy: 0.9739 - val_loss: 2.6266 - val_accuracy: 0.5556
# Epoch 46/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0529 - accuracy: 0.9823 - val_loss: 2.8930 - val_accuracy: 0.5354
# Epoch 47/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0393 - accuracy: 0.9882 - val_loss: 3.3372 - val_accuracy: 0.5253
# Epoch 48/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0413 - accuracy: 0.9840 - val_loss: 3.4589 - val_accuracy: 0.5118
# Epoch 49/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0449 - accuracy: 0.9857 - val_loss: 3.0906 - val_accuracy: 0.5219
# Epoch 50/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0486 - accuracy: 0.9832 - val_loss: 3.2153 - val_accuracy: 0.5522
# Epoch 51/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0512 - accuracy: 0.9848 - val_loss: 3.1474 - val_accuracy: 0.5589
# Epoch 52/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0634 - accuracy: 0.9815 - val_loss: 3.4194 - val_accuracy: 0.5320
# Epoch 53/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0441 - accuracy: 0.9823 - val_loss: 3.2774 - val_accuracy: 0.5253
# Epoch 54/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0535 - accuracy: 0.9857 - val_loss: 3.5676 - val_accuracy: 0.5354
# Epoch 55/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0434 - accuracy: 0.9848 - val_loss: 3.1733 - val_accuracy: 0.5488
# Epoch 56/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0333 - accuracy: 0.9891 - val_loss: 3.1093 - val_accuracy: 0.5488
# Epoch 57/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0298 - accuracy: 0.9924 - val_loss: 3.4994 - val_accuracy: 0.5623
# Epoch 58/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0476 - accuracy: 0.9840 - val_loss: 3.4064 - val_accuracy: 0.5455
# Epoch 59/100
# 38/38 [==============================] - 5s 125ms/step - loss: 0.0386 - accuracy: 0.9882 - val_loss: 3.5875 - val_accuracy: 0.5286
# Epoch 60/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1396 - accuracy: 0.9554 - val_loss: 2.9020 - val_accuracy: 0.5185
# Epoch 61/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.1164 - accuracy: 0.9604 - val_loss: 3.1248 - val_accuracy: 0.5657
# Epoch 62/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0625 - accuracy: 0.9806 - val_loss: 2.9691 - val_accuracy: 0.5623
# Epoch 63/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0446 - accuracy: 0.9848 - val_loss: 3.2620 - val_accuracy: 0.5623
# Epoch 64/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0278 - accuracy: 0.9916 - val_loss: 3.4708 - val_accuracy: 0.5421
# Epoch 65/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0207 - accuracy: 0.9949 - val_loss: 3.4791 - val_accuracy: 0.5758
# Epoch 66/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0297 - accuracy: 0.9899 - val_loss: 3.5187 - val_accuracy: 0.5657
# Epoch 67/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0259 - accuracy: 0.9899 - val_loss: 3.3103 - val_accuracy: 0.5556
# Epoch 68/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0307 - accuracy: 0.9933 - val_loss: 3.6063 - val_accuracy: 0.5589
# Epoch 69/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0219 - accuracy: 0.9924 - val_loss: 3.5541 - val_accuracy: 0.5623
# Epoch 70/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0182 - accuracy: 0.9958 - val_loss: 3.5703 - val_accuracy: 0.5421
# Epoch 71/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0167 - accuracy: 0.9924 - val_loss: 3.6563 - val_accuracy: 0.5387
# Epoch 72/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0186 - accuracy: 0.9933 - val_loss: 3.5450 - val_accuracy: 0.5589
# Epoch 73/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 3.8937 - val_accuracy: 0.5488
# Epoch 74/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0332 - accuracy: 0.9891 - val_loss: 3.4785 - val_accuracy: 0.5522
# Epoch 75/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0188 - accuracy: 0.9916 - val_loss: 3.6272 - val_accuracy: 0.5623
# Epoch 76/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 3.6405 - val_accuracy: 0.5657
# Epoch 77/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0187 - accuracy: 0.9916 - val_loss: 3.7995 - val_accuracy: 0.5825
# Epoch 78/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 3.9186 - val_accuracy: 0.5488
# Epoch 79/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0236 - accuracy: 0.9924 - val_loss: 4.4784 - val_accuracy: 0.5084
# Epoch 80/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0357 - accuracy: 0.9899 - val_loss: 3.8733 - val_accuracy: 0.5522
# Epoch 81/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0349 - accuracy: 0.9882 - val_loss: 3.6408 - val_accuracy: 0.5219
# Epoch 82/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0282 - accuracy: 0.9916 - val_loss: 3.6514 - val_accuracy: 0.5219
# Epoch 83/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0168 - accuracy: 0.9941 - val_loss: 3.7810 - val_accuracy: 0.5387
# Epoch 84/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0300 - accuracy: 0.9924 - val_loss: 4.0605 - val_accuracy: 0.5253
# Epoch 85/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0135 - accuracy: 0.9941 - val_loss: 4.0342 - val_accuracy: 0.5253
# Epoch 86/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0333 - accuracy: 0.9865 - val_loss: 3.6733 - val_accuracy: 0.5286
# Epoch 87/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0256 - accuracy: 0.9899 - val_loss: 3.4952 - val_accuracy: 0.5354
# Epoch 88/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0319 - accuracy: 0.9907 - val_loss: 3.7870 - val_accuracy: 0.5354
# Epoch 89/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 4.1794 - val_accuracy: 0.5320
# Epoch 90/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0140 - accuracy: 0.9958 - val_loss: 4.1728 - val_accuracy: 0.5455
# Epoch 91/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0344 - accuracy: 0.9907 - val_loss: 4.0589 - val_accuracy: 0.4882
# Epoch 92/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0428 - accuracy: 0.9865 - val_loss: 4.1182 - val_accuracy: 0.5152
# Epoch 93/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0463 - accuracy: 0.9848 - val_loss: 3.6578 - val_accuracy: 0.5556
# Epoch 94/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0374 - accuracy: 0.9916 - val_loss: 3.7538 - val_accuracy: 0.5354
# Epoch 95/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0266 - accuracy: 0.9933 - val_loss: 3.8285 - val_accuracy: 0.5556
# Epoch 96/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0312 - accuracy: 0.9882 - val_loss: 4.1782 - val_accuracy: 0.4949
# Epoch 97/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0279 - accuracy: 0.9916 - val_loss: 3.9149 - val_accuracy: 0.5421
# Epoch 98/100
# 38/38 [==============================] - 5s 123ms/step - loss: 0.0153 - accuracy: 0.9933 - val_loss: 4.0502 - val_accuracy: 0.5320
# Epoch 99/100
# 38/38 [==============================] - 5s 122ms/step - loss: 0.0409 - accuracy: 0.9815 - val_loss: 3.4671 - val_accuracy: 0.5320
# Epoch 100/100
# 38/38 [==============================] - 5s 124ms/step - loss: 0.0251 - accuracy: 0.9907 - val_loss: 3.4777 - val_accuracy: 0.5253

# %%
model.save('/kaggle/working/model.h5')

# %%
from matplotlib import pyplot as plt
# plot the training loss and accuracy
N = 100 #number of epochs
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("CNN_Model")

# %%
vaL_loss, val_accuracy= model.evaluate(x_test, y_test, verbose=0)
print("test loss:", vaL_loss,'%')
print("test accuracy:", val_accuracy,"%")
# Out:
# test loss: 3.401653528213501 %
# test accuracy: 0.5575757622718811 %

# %%
X = 32
img_size = 256
img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = (np.expand_dims(img_single, 0))
img_single = img_single.reshape(img_single.shape[0],256,256,1)

predictions_single = model.predict(img_single)
print('A.I predicts:',categories[np.argmax(predictions_single)])
print("Correct prediction for label",np.argmax(y_test[X]),'is',categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 0s 281ms/step
# A.I predicts: 0Normal
# Correct prediction for label 4 is 0Normal

# %%
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)

cm  = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm,figsize=(12,8), hide_ticks=True,cmap=plt.cm.Blues)
plt.xticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.yticks(range(5), ['Normal','Doubtful','Mid','Moderate','Severe'], fontsize=16)
plt.show()
# Out:
# 6/6 [==============================] - 0s 37ms/step
