# %%
import cv2
import os
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, GlobalAveragePooling2D, Dropout
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix
from keras.applications import DenseNet201
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
# Set the data path and categories
data_path = '/kaggle/input/koa-1500/MedicalExpert-I'
categories = os.listdir(data_path)
labels = [i for i in range(len(categories))]

label_dict = dict(zip(categories, labels))

img_size = 256
data = []
label = []

# Load the images and labels
for category in categories:
    folder_path = os.path.join(data_path, category)
    img_names = os.listdir(folder_path)

    for img_name in img_names:
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized = cv2.resize(gray, (img_size, img_size))
            data.append(resized)
            label.append(label_dict[category])
        except Exception as e:
            print('Exception:', e)

# %%
data = np.array(data) / 255.0
data_rgb = np.repeat(data[..., np.newaxis], 3, -1)
label = np.array(label)
new_label = np_utils.to_categorical(label)

# Split the data into train, test, and validation sets
x_train, x_test, y_train, y_test = train_test_split(data_rgb, new_label, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.125, random_state=42)

# Define the data generators
datagen_train = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
)

datagen_val = ImageDataGenerator()

train_generator = datagen_train.flow(x_train, y_train, batch_size=32)
val_generator = datagen_val.flow(x_val, y_val, batch_size=32)

# %%
# Define the model architecture
model = Sequential()

# DenseNet201
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

model.add(base_model)
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(len(categories), activation='softmax'))

# Compile the model
model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet201 (Functional)    (None, 8, 8, 1920)        18321984
#
#  global_average_pooling2d (G  (None, 1920)             0
#  lobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 1920)              0
#
#  dense (Dense)               (None, 5)                 9605
#
# =================================================================
# Total params: 18,331,589
# Trainable params: 18,102,533
# Non-trainable params: 229,056
# _________________________________________________________________

# %%
# Set up a checkpoint to save the best model
checkpoint = ModelCheckpoint('/kaggle/working/model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Set up early stopping
#early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
# Train the model
history = model.fit(train_generator,
                    epochs=60,
                    validation_data=val_generator,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/60
# 37/37 [==============================] - ETA: 0s - loss: 1.3610 - accuracy: 0.4597
# Epoch 1: val_accuracy improved from -inf to 0.27879, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 83s 1s/step - loss: 1.3610 - accuracy: 0.4597 - val_loss: 1.9923 - val_accuracy: 0.2788
# Epoch 2/60
# 37/37 [==============================] - ETA: 0s - loss: 0.9444 - accuracy: 0.6216
# Epoch 2: val_accuracy improved from 0.27879 to 0.35152, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 784ms/step - loss: 0.9444 - accuracy: 0.6216 - val_loss: 1.9292 - val_accuracy: 0.3515
# Epoch 3/60
# 37/37 [==============================] - ETA: 0s - loss: 0.7844 - accuracy: 0.6970
# Epoch 3: val_accuracy improved from 0.35152 to 0.40000, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 773ms/step - loss: 0.7844 - accuracy: 0.6970 - val_loss: 1.4789 - val_accuracy: 0.4000
# Epoch 4/60
# 37/37 [==============================] - ETA: 0s - loss: 0.7364 - accuracy: 0.6944
# Epoch 4: val_accuracy improved from 0.40000 to 0.44848, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 30s 791ms/step - loss: 0.7364 - accuracy: 0.6944 - val_loss: 1.4932 - val_accuracy: 0.4485
# Epoch 5/60
# 37/37 [==============================] - ETA: 0s - loss: 0.6361 - accuracy: 0.7628
# Epoch 5: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 26s 703ms/step - loss: 0.6361 - accuracy: 0.7628 - val_loss: 1.7430 - val_accuracy: 0.4485
# Epoch 6/60
# 37/37 [==============================] - ETA: 0s - loss: 0.5879 - accuracy: 0.7602
# Epoch 6: val_accuracy improved from 0.44848 to 0.48485, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 774ms/step - loss: 0.5879 - accuracy: 0.7602 - val_loss: 1.3620 - val_accuracy: 0.4848
# Epoch 7/60
# 37/37 [==============================] - ETA: 0s - loss: 0.5690 - accuracy: 0.7853
# Epoch 7: val_accuracy improved from 0.48485 to 0.59394, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 779ms/step - loss: 0.5690 - accuracy: 0.7853 - val_loss: 1.3520 - val_accuracy: 0.5939
# Epoch 8/60
# 37/37 [==============================] - ETA: 0s - loss: 0.5292 - accuracy: 0.8000
# Epoch 8: val_accuracy improved from 0.59394 to 0.63030, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 30s 798ms/step - loss: 0.5292 - accuracy: 0.8000 - val_loss: 0.9667 - val_accuracy: 0.6303
# Epoch 9/60
# 37/37 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8442
# Epoch 9: val_accuracy did not improve from 0.63030
# 37/37 [==============================] - 27s 713ms/step - loss: 0.4183 - accuracy: 0.8442 - val_loss: 1.9253 - val_accuracy: 0.4909
# Epoch 10/60
# 37/37 [==============================] - ETA: 0s - loss: 0.4002 - accuracy: 0.8286
# Epoch 10: val_accuracy improved from 0.63030 to 0.64242, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 788ms/step - loss: 0.4002 - accuracy: 0.8286 - val_loss: 0.9538 - val_accuracy: 0.6424
# Epoch 11/60
# 37/37 [==============================] - ETA: 0s - loss: 0.4203 - accuracy: 0.8390
# Epoch 11: val_accuracy did not improve from 0.64242
# 37/37 [==============================] - 26s 704ms/step - loss: 0.4203 - accuracy: 0.8390 - val_loss: 2.3533 - val_accuracy: 0.4848
# Epoch 12/60
# 37/37 [==============================] - ETA: 0s - loss: 0.4258 - accuracy: 0.8372
# Epoch 12: val_accuracy did not improve from 0.64242
# 37/37 [==============================] - 27s 727ms/step - loss: 0.4258 - accuracy: 0.8372 - val_loss: 1.1919 - val_accuracy: 0.5455
# Epoch 13/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3940 - accuracy: 0.8494
# Epoch 13: val_accuracy did not improve from 0.64242
# 37/37 [==============================] - 27s 731ms/step - loss: 0.3940 - accuracy: 0.8494 - val_loss: 1.6888 - val_accuracy: 0.6061
# Epoch 14/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3834 - accuracy: 0.8597
# Epoch 14: val_accuracy improved from 0.64242 to 0.66061, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 771ms/step - loss: 0.3834 - accuracy: 0.8597 - val_loss: 1.1591 - val_accuracy: 0.6606
# Epoch 15/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.8779
# Epoch 15: val_accuracy did not improve from 0.66061
# 37/37 [==============================] - 26s 725ms/step - loss: 0.3648 - accuracy: 0.8779 - val_loss: 1.4518 - val_accuracy: 0.5818
# Epoch 16/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3100 - accuracy: 0.8745
# Epoch 16: val_accuracy did not improve from 0.66061
# 37/37 [==============================] - 27s 714ms/step - loss: 0.3100 - accuracy: 0.8745 - val_loss: 1.1576 - val_accuracy: 0.6182
# Epoch 17/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3185 - accuracy: 0.8779
# Epoch 17: val_accuracy improved from 0.66061 to 0.75152, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 30s 791ms/step - loss: 0.3185 - accuracy: 0.8779 - val_loss: 0.7900 - val_accuracy: 0.7515
# Epoch 18/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2755 - accuracy: 0.8961
# Epoch 18: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 714ms/step - loss: 0.2755 - accuracy: 0.8961 - val_loss: 1.0076 - val_accuracy: 0.7212
# Epoch 19/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3351 - accuracy: 0.8779
# Epoch 19: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 720ms/step - loss: 0.3351 - accuracy: 0.8779 - val_loss: 1.6142 - val_accuracy: 0.5879
# Epoch 20/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.8909
# Epoch 20: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 714ms/step - loss: 0.2936 - accuracy: 0.8909 - val_loss: 3.5663 - val_accuracy: 0.3455
# Epoch 21/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.8727
# Epoch 21: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 713ms/step - loss: 0.3111 - accuracy: 0.8727 - val_loss: 2.4632 - val_accuracy: 0.4970
# Epoch 22/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2401 - accuracy: 0.9108
# Epoch 22: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 713ms/step - loss: 0.2401 - accuracy: 0.9108 - val_loss: 1.3512 - val_accuracy: 0.5939
# Epoch 23/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2367 - accuracy: 0.9169
# Epoch 23: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 712ms/step - loss: 0.2367 - accuracy: 0.9169 - val_loss: 1.2364 - val_accuracy: 0.7212
# Epoch 24/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2206 - accuracy: 0.9117
# Epoch 24: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 26s 702ms/step - loss: 0.2206 - accuracy: 0.9117 - val_loss: 2.2425 - val_accuracy: 0.5394
# Epoch 25/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2656 - accuracy: 0.9065
# Epoch 25: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 711ms/step - loss: 0.2656 - accuracy: 0.9065 - val_loss: 2.3981 - val_accuracy: 0.4667
# Epoch 26/60
# 37/37 [==============================] - ETA: 0s - loss: 0.3271 - accuracy: 0.8727
# Epoch 26: val_accuracy did not improve from 0.75152
# 37/37 [==============================] - 27s 735ms/step - loss: 0.3271 - accuracy: 0.8727 - val_loss: 1.3409 - val_accuracy: 0.6303
# Epoch 27/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2446 - accuracy: 0.9074
# Epoch 27: val_accuracy improved from 0.75152 to 0.76364, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 778ms/step - loss: 0.2446 - accuracy: 0.9074 - val_loss: 0.6828 - val_accuracy: 0.7636
# Epoch 28/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2125 - accuracy: 0.9186
# Epoch 28: val_accuracy did not improve from 0.76364
# 37/37 [==============================] - 27s 715ms/step - loss: 0.2125 - accuracy: 0.9186 - val_loss: 0.9409 - val_accuracy: 0.6909
# Epoch 29/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2076 - accuracy: 0.9333
# Epoch 29: val_accuracy improved from 0.76364 to 0.80606, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 29s 784ms/step - loss: 0.2076 - accuracy: 0.9333 - val_loss: 0.7219 - val_accuracy: 0.8061
# Epoch 30/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9316
# Epoch 30: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 714ms/step - loss: 0.1878 - accuracy: 0.9316 - val_loss: 0.9433 - val_accuracy: 0.7697
# Epoch 31/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1998 - accuracy: 0.9342
# Epoch 31: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 730ms/step - loss: 0.1998 - accuracy: 0.9342 - val_loss: 1.5733 - val_accuracy: 0.6121
# Epoch 32/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9359
# Epoch 32: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 717ms/step - loss: 0.1792 - accuracy: 0.9359 - val_loss: 0.8070 - val_accuracy: 0.7273
# Epoch 33/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9299
# Epoch 33: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 717ms/step - loss: 0.1910 - accuracy: 0.9299 - val_loss: 1.0250 - val_accuracy: 0.7091
# Epoch 34/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2644 - accuracy: 0.9030
# Epoch 34: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 28s 735ms/step - loss: 0.2644 - accuracy: 0.9030 - val_loss: 1.2477 - val_accuracy: 0.6848
# Epoch 35/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2426 - accuracy: 0.9117
# Epoch 35: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 722ms/step - loss: 0.2426 - accuracy: 0.9117 - val_loss: 2.0663 - val_accuracy: 0.5636
# Epoch 36/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9550
# Epoch 36: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 714ms/step - loss: 0.1346 - accuracy: 0.9550 - val_loss: 1.8178 - val_accuracy: 0.5636
# Epoch 37/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9411
# Epoch 37: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 26s 707ms/step - loss: 0.1813 - accuracy: 0.9411 - val_loss: 2.0315 - val_accuracy: 0.6364
# Epoch 38/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9602
# Epoch 38: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 710ms/step - loss: 0.1287 - accuracy: 0.9602 - val_loss: 1.0362 - val_accuracy: 0.7152
# Epoch 39/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9472
# Epoch 39: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 719ms/step - loss: 0.1656 - accuracy: 0.9472 - val_loss: 1.0439 - val_accuracy: 0.6848
# Epoch 40/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9472
# Epoch 40: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 718ms/step - loss: 0.1419 - accuracy: 0.9472 - val_loss: 1.6311 - val_accuracy: 0.7273
# Epoch 41/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1338 - accuracy: 0.9541
# Epoch 41: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 716ms/step - loss: 0.1338 - accuracy: 0.9541 - val_loss: 1.1029 - val_accuracy: 0.6242
# Epoch 42/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1273 - accuracy: 0.9541
# Epoch 42: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 714ms/step - loss: 0.1273 - accuracy: 0.9541 - val_loss: 1.5241 - val_accuracy: 0.5758
# Epoch 43/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1837 - accuracy: 0.9333
# Epoch 43: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 728ms/step - loss: 0.1837 - accuracy: 0.9333 - val_loss: 1.8819 - val_accuracy: 0.5030
# Epoch 44/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9385
# Epoch 44: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 727ms/step - loss: 0.1644 - accuracy: 0.9385 - val_loss: 1.1867 - val_accuracy: 0.7091
# Epoch 45/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9264
# Epoch 45: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 714ms/step - loss: 0.2098 - accuracy: 0.9264 - val_loss: 1.5791 - val_accuracy: 0.5697
# Epoch 46/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1728 - accuracy: 0.9325
# Epoch 46: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 713ms/step - loss: 0.1728 - accuracy: 0.9325 - val_loss: 0.8840 - val_accuracy: 0.7636
# Epoch 47/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1589 - accuracy: 0.9394
# Epoch 47: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 714ms/step - loss: 0.1589 - accuracy: 0.9394 - val_loss: 1.5019 - val_accuracy: 0.6667
# Epoch 48/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9472
# Epoch 48: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 26s 704ms/step - loss: 0.1528 - accuracy: 0.9472 - val_loss: 1.9509 - val_accuracy: 0.4970
# Epoch 49/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1289 - accuracy: 0.9532
# Epoch 49: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 713ms/step - loss: 0.1289 - accuracy: 0.9532 - val_loss: 1.6344 - val_accuracy: 0.6000
# Epoch 50/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9532
# Epoch 50: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 727ms/step - loss: 0.1351 - accuracy: 0.9532 - val_loss: 1.1918 - val_accuracy: 0.6485
# Epoch 51/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1212 - accuracy: 0.9558
# Epoch 51: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 716ms/step - loss: 0.1212 - accuracy: 0.9558 - val_loss: 1.2950 - val_accuracy: 0.6909
# Epoch 52/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1612 - accuracy: 0.9368
# Epoch 52: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 718ms/step - loss: 0.1612 - accuracy: 0.9368 - val_loss: 0.9827 - val_accuracy: 0.7333
# Epoch 53/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9446
# Epoch 53: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 26s 694ms/step - loss: 0.1420 - accuracy: 0.9446 - val_loss: 0.7068 - val_accuracy: 0.7636
# Epoch 54/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1235 - accuracy: 0.9593
# Epoch 54: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 704ms/step - loss: 0.1235 - accuracy: 0.9593 - val_loss: 0.7770 - val_accuracy: 0.7818
# Epoch 55/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1027 - accuracy: 0.9610
# Epoch 55: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 723ms/step - loss: 0.1027 - accuracy: 0.9610 - val_loss: 1.1237 - val_accuracy: 0.7091
# Epoch 56/60
# 37/37 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9307
# Epoch 56: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 712ms/step - loss: 0.2219 - accuracy: 0.9307 - val_loss: 7.3644 - val_accuracy: 0.2182
# Epoch 57/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1807 - accuracy: 0.9351
# Epoch 57: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 704ms/step - loss: 0.1807 - accuracy: 0.9351 - val_loss: 1.0254 - val_accuracy: 0.6545
# Epoch 58/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1614 - accuracy: 0.9403
# Epoch 58: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 719ms/step - loss: 0.1614 - accuracy: 0.9403 - val_loss: 1.9683 - val_accuracy: 0.5333
# Epoch 59/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9541
# Epoch 59: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 26s 703ms/step - loss: 0.1148 - accuracy: 0.9541 - val_loss: 1.3881 - val_accuracy: 0.6848
# Epoch 60/60
# 37/37 [==============================] - ETA: 0s - loss: 0.1118 - accuracy: 0.9515
# Epoch 60: val_accuracy did not improve from 0.80606
# 37/37 [==============================] - 27s 715ms/step - loss: 0.1118 - accuracy: 0.9515 - val_loss: 0.5992 - val_accuracy: 0.8061

# %%
# Load the best weights
model.load_weights('/kaggle/working/model.h5')

# %%
# Plot the training loss and accuracy
N = len(history.history['loss'])
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, N), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, N), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, N), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, N), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("InceptionResNetV2_Model")

# %%
# Evaluate the model on the test set
val_loss, val_accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", val_loss)
print("Test accuracy:", val_accuracy)

# Get the predictions for the test set
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=-1)

# Generate the classification report
report = classification_report(np.argmax(y_test, axis=1), predicted_labels)
print(report)
# Out:
# Test loss: 0.5265874862670898
# Test accuracy: 0.8303030133247375
# 11/11 [==============================] - 5s 177ms/step
#               precision    recall  f1-score   support
#
#            0       0.88      0.71      0.79       105
#            1       0.84      0.94      0.89        50
#            2       0.89      0.78      0.83        32
#            3       0.73      0.73      0.73        48
#            4       0.81      0.97      0.88        95
#
#     accuracy                           0.83       330
#    macro avg       0.83      0.83      0.82       330
# weighted avg       0.83      0.83      0.83       330

# %%
# Plot the confusion matrix
test_labels = np.argmax(y_test, axis=1)
cm = confusion_matrix(test_labels, predicted_labels)
plt.figure()
plot_confusion_matrix(cm, figsize=(12, 8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(len(categories)), categories, fontsize=12)
plt.yticks(range(len(categories)), categories, fontsize=12)
plt.show()

# %%
# Select a single image from the test set for prediction
X = 32
img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = np.expand_dims(img_single, 0)

# Make prediction on the single image
predictions_single = model.predict(img_single)
print('A.I predicts:', categories[np.argmax(predictions_single)])
print("Correct prediction for label", np.argmax(y_test[X]), 'is', categories[np.argmax(y_test[X])])

# Display the single image
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# A.I predicts: 3Moderate
# Correct prediction for label 1 is 3Moderate
