# %%
import cv2
import os
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
from keras.applications.vgg16 import VGG16
from keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
data_path = '/kaggle/input/koa-1500/MedicalExpert-I'
categories = os.listdir(data_path)
labels = [i for i in range(len(categories))]

label_dict = dict(zip(categories, labels))

img_size = 256
data = []
label = []

# %%
for category in categories:
    folder_path = os.path.join(data_path, category)
    img_names = os.listdir(folder_path)

    for img_name in img_names:
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized = cv2.resize(gray, (img_size, img_size))
            data.append(resized)
            label.append(label_dict[category])
        except Exception as e:
            print('Exception:', e)

# %%
data = np.array(data) / 255.0
data_rgb = np.repeat(data[..., np.newaxis], 3, -1)
label = np.array(label)
new_label = np_utils.to_categorical(label)

x_train, x_test, y_train, y_test = train_test_split(data_rgb, new_label, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.125, random_state=42)

datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

datagen.fit(x_train)

# %%
model = Sequential()
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))
model.add(base_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(categories), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 512)               16777728
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 31,494,981
# Trainable params: 31,494,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint('/kaggle/working/model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# %%
history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=50,
                    validation_data=(x_val, y_val),
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 37/37 [==============================] - ETA: 0s - loss: 1.6158 - accuracy: 0.2866
# Epoch 1: val_accuracy improved from -inf to 0.27273, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 53s 794ms/step - loss: 1.6158 - accuracy: 0.2866 - val_loss: 1.5621 - val_accuracy: 0.2727
# Epoch 2/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5405 - accuracy: 0.3117
# Epoch 2: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 23s 613ms/step - loss: 1.5405 - accuracy: 0.3117 - val_loss: 1.5557 - val_accuracy: 0.2727
# Epoch 3/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5318 - accuracy: 0.3177
# Epoch 3: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 24s 648ms/step - loss: 1.5318 - accuracy: 0.3177 - val_loss: 1.5606 - val_accuracy: 0.2727
# Epoch 4/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5384 - accuracy: 0.3195
# Epoch 4: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 24s 637ms/step - loss: 1.5384 - accuracy: 0.3195 - val_loss: 1.5469 - val_accuracy: 0.2727
# Epoch 5/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5318 - accuracy: 0.2978
# Epoch 5: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 24s 629ms/step - loss: 1.5318 - accuracy: 0.2978 - val_loss: 1.5504 - val_accuracy: 0.2727
# Epoch 6/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5204 - accuracy: 0.3126
# Epoch 6: val_accuracy improved from 0.27273 to 0.30909, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 678ms/step - loss: 1.5204 - accuracy: 0.3126 - val_loss: 1.5498 - val_accuracy: 0.3091
# Epoch 7/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5135 - accuracy: 0.3238
# Epoch 7: val_accuracy did not improve from 0.30909
# 37/37 [==============================] - 24s 631ms/step - loss: 1.5135 - accuracy: 0.3238 - val_loss: 1.5337 - val_accuracy: 0.2909
# Epoch 8/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5471 - accuracy: 0.2952
# Epoch 8: val_accuracy did not improve from 0.30909
# 37/37 [==============================] - 24s 635ms/step - loss: 1.5471 - accuracy: 0.2952 - val_loss: 1.5425 - val_accuracy: 0.2606
# Epoch 9/50
# 37/37 [==============================] - ETA: 0s - loss: 1.5025 - accuracy: 0.3177
# Epoch 9: val_accuracy improved from 0.30909 to 0.31515, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 24s 647ms/step - loss: 1.5025 - accuracy: 0.3177 - val_loss: 1.5355 - val_accuracy: 0.3152
# Epoch 10/50
# 37/37 [==============================] - ETA: 0s - loss: 1.4926 - accuracy: 0.3273
# Epoch 10: val_accuracy improved from 0.31515 to 0.38182, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 26s 691ms/step - loss: 1.4926 - accuracy: 0.3273 - val_loss: 1.4498 - val_accuracy: 0.3818
# Epoch 11/50
# 37/37 [==============================] - ETA: 0s - loss: 1.4682 - accuracy: 0.3429
# Epoch 11: val_accuracy did not improve from 0.38182
# 37/37 [==============================] - 24s 635ms/step - loss: 1.4682 - accuracy: 0.3429 - val_loss: 1.4230 - val_accuracy: 0.3515
# Epoch 12/50
# 37/37 [==============================] - ETA: 0s - loss: 1.4162 - accuracy: 0.3870
# Epoch 12: val_accuracy improved from 0.38182 to 0.39394, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 24s 677ms/step - loss: 1.4162 - accuracy: 0.3870 - val_loss: 1.3810 - val_accuracy: 0.3939
# Epoch 13/50
# 37/37 [==============================] - ETA: 0s - loss: 1.3820 - accuracy: 0.4165
# Epoch 13: val_accuracy did not improve from 0.39394
# 37/37 [==============================] - 23s 619ms/step - loss: 1.3820 - accuracy: 0.4165 - val_loss: 1.4406 - val_accuracy: 0.3697
# Epoch 14/50
# 37/37 [==============================] - ETA: 0s - loss: 1.3563 - accuracy: 0.4095
# Epoch 14: val_accuracy did not improve from 0.39394
# 37/37 [==============================] - 24s 640ms/step - loss: 1.3563 - accuracy: 0.4095 - val_loss: 1.4432 - val_accuracy: 0.3818
# Epoch 15/50
# 37/37 [==============================] - ETA: 0s - loss: 1.3091 - accuracy: 0.4476
# Epoch 15: val_accuracy improved from 0.39394 to 0.40606, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 656ms/step - loss: 1.3091 - accuracy: 0.4476 - val_loss: 1.3472 - val_accuracy: 0.4061
# Epoch 16/50
# 37/37 [==============================] - ETA: 0s - loss: 1.2544 - accuracy: 0.4745
# Epoch 16: val_accuracy improved from 0.40606 to 0.43636, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 676ms/step - loss: 1.2544 - accuracy: 0.4745 - val_loss: 1.2652 - val_accuracy: 0.4364
# Epoch 17/50
# 37/37 [==============================] - ETA: 0s - loss: 1.2165 - accuracy: 0.5048
# Epoch 17: val_accuracy improved from 0.43636 to 0.50909, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 657ms/step - loss: 1.2165 - accuracy: 0.5048 - val_loss: 1.2195 - val_accuracy: 0.5091
# Epoch 18/50
# 37/37 [==============================] - ETA: 0s - loss: 1.1696 - accuracy: 0.5160
# Epoch 18: val_accuracy did not improve from 0.50909
# 37/37 [==============================] - 23s 618ms/step - loss: 1.1696 - accuracy: 0.5160 - val_loss: 1.3003 - val_accuracy: 0.4242
# Epoch 19/50
# 37/37 [==============================] - ETA: 0s - loss: 1.1394 - accuracy: 0.5359
# Epoch 19: val_accuracy improved from 0.50909 to 0.57576, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 661ms/step - loss: 1.1394 - accuracy: 0.5359 - val_loss: 1.1148 - val_accuracy: 0.5758
# Epoch 20/50
# 37/37 [==============================] - ETA: 0s - loss: 1.1181 - accuracy: 0.5351
# Epoch 20: val_accuracy did not improve from 0.57576
# 37/37 [==============================] - 24s 636ms/step - loss: 1.1181 - accuracy: 0.5351 - val_loss: 1.0730 - val_accuracy: 0.5455
# Epoch 21/50
# 37/37 [==============================] - ETA: 0s - loss: 1.0955 - accuracy: 0.5446
# Epoch 21: val_accuracy improved from 0.57576 to 0.58788, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 662ms/step - loss: 1.0955 - accuracy: 0.5446 - val_loss: 1.0478 - val_accuracy: 0.5879
# Epoch 22/50
# 37/37 [==============================] - ETA: 0s - loss: 1.0012 - accuracy: 0.5974
# Epoch 22: val_accuracy did not improve from 0.58788
# 37/37 [==============================] - 24s 645ms/step - loss: 1.0012 - accuracy: 0.5974 - val_loss: 1.0446 - val_accuracy: 0.5697
# Epoch 23/50
# 37/37 [==============================] - ETA: 0s - loss: 0.9920 - accuracy: 0.5931
# Epoch 23: val_accuracy did not improve from 0.58788
# 37/37 [==============================] - 24s 643ms/step - loss: 0.9920 - accuracy: 0.5931 - val_loss: 1.1380 - val_accuracy: 0.5333
# Epoch 24/50
# 37/37 [==============================] - ETA: 0s - loss: 0.9159 - accuracy: 0.6277
# Epoch 24: val_accuracy improved from 0.58788 to 0.61212, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 659ms/step - loss: 0.9159 - accuracy: 0.6277 - val_loss: 0.9026 - val_accuracy: 0.6121
# Epoch 25/50
# 37/37 [==============================] - ETA: 0s - loss: 0.9042 - accuracy: 0.6329
# Epoch 25: val_accuracy improved from 0.61212 to 0.63636, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 677ms/step - loss: 0.9042 - accuracy: 0.6329 - val_loss: 0.8516 - val_accuracy: 0.6364
# Epoch 26/50
# 37/37 [==============================] - ETA: 0s - loss: 0.8399 - accuracy: 0.6597
# Epoch 26: val_accuracy improved from 0.63636 to 0.71515, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 670ms/step - loss: 0.8399 - accuracy: 0.6597 - val_loss: 0.8036 - val_accuracy: 0.7152
# Epoch 27/50
# 37/37 [==============================] - ETA: 0s - loss: 0.9743 - accuracy: 0.6225
# Epoch 27: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 23s 615ms/step - loss: 0.9743 - accuracy: 0.6225 - val_loss: 0.8655 - val_accuracy: 0.6667
# Epoch 28/50
# 37/37 [==============================] - ETA: 0s - loss: 0.8476 - accuracy: 0.6528
# Epoch 28: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 24s 637ms/step - loss: 0.8476 - accuracy: 0.6528 - val_loss: 0.8687 - val_accuracy: 0.6364
# Epoch 29/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7994 - accuracy: 0.6840
# Epoch 29: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 24s 638ms/step - loss: 0.7994 - accuracy: 0.6840 - val_loss: 0.7454 - val_accuracy: 0.7030
# Epoch 30/50
# 37/37 [==============================] - ETA: 0s - loss: 0.8119 - accuracy: 0.6623
# Epoch 30: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 24s 637ms/step - loss: 0.8119 - accuracy: 0.6623 - val_loss: 0.9338 - val_accuracy: 0.6061
# Epoch 31/50
# 37/37 [==============================] - ETA: 0s - loss: 0.8115 - accuracy: 0.6736
# Epoch 31: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 24s 644ms/step - loss: 0.8115 - accuracy: 0.6736 - val_loss: 0.8258 - val_accuracy: 0.6606
# Epoch 32/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7692 - accuracy: 0.6944
# Epoch 32: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 23s 622ms/step - loss: 0.7692 - accuracy: 0.6944 - val_loss: 0.8754 - val_accuracy: 0.6242
# Epoch 33/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7278 - accuracy: 0.7013
# Epoch 33: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 23s 612ms/step - loss: 0.7278 - accuracy: 0.7013 - val_loss: 0.8239 - val_accuracy: 0.6545
# Epoch 34/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7434 - accuracy: 0.7039
# Epoch 34: val_accuracy did not improve from 0.71515
# 37/37 [==============================] - 23s 625ms/step - loss: 0.7434 - accuracy: 0.7039 - val_loss: 0.7574 - val_accuracy: 0.6909
# Epoch 35/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7401 - accuracy: 0.7108
# Epoch 35: val_accuracy improved from 0.71515 to 0.72727, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 659ms/step - loss: 0.7401 - accuracy: 0.7108 - val_loss: 0.7060 - val_accuracy: 0.7273
# Epoch 36/50
# 37/37 [==============================] - ETA: 0s - loss: 0.6924 - accuracy: 0.7212
# Epoch 36: val_accuracy did not improve from 0.72727
# 37/37 [==============================] - 24s 635ms/step - loss: 0.6924 - accuracy: 0.7212 - val_loss: 0.8991 - val_accuracy: 0.6364
# Epoch 37/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7247 - accuracy: 0.7117
# Epoch 37: val_accuracy did not improve from 0.72727
# 37/37 [==============================] - 23s 619ms/step - loss: 0.7247 - accuracy: 0.7117 - val_loss: 0.7822 - val_accuracy: 0.6970
# Epoch 38/50
# 37/37 [==============================] - ETA: 0s - loss: 0.7491 - accuracy: 0.6866
# Epoch 38: val_accuracy did not improve from 0.72727
# 37/37 [==============================] - 23s 613ms/step - loss: 0.7491 - accuracy: 0.6866 - val_loss: 0.7494 - val_accuracy: 0.6848
# Epoch 39/50
# 37/37 [==============================] - ETA: 0s - loss: 0.6253 - accuracy: 0.7654
# Epoch 44: val_accuracy did not improve from 0.73939
# 37/37 [==============================] - 23s 616ms/step - loss: 0.6253 - accuracy: 0.7654 - val_loss: 0.6631 - val_accuracy: 0.7152
# Epoch 45/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5933 - accuracy: 0.7810
# Epoch 45: val_accuracy did not improve from 0.73939
# 37/37 [==============================] - 23s 625ms/step - loss: 0.5933 - accuracy: 0.7810 - val_loss: 0.7633 - val_accuracy: 0.7212
# Epoch 46/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5606 - accuracy: 0.7801
# Epoch 46: val_accuracy improved from 0.73939 to 0.74545, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 25s 657ms/step - loss: 0.5606 - accuracy: 0.7801 - val_loss: 0.6347 - val_accuracy: 0.7455
# Epoch 47/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5821 - accuracy: 0.7775
# Epoch 47: val_accuracy did not improve from 0.74545
# 37/37 [==============================] - 23s 616ms/step - loss: 0.5821 - accuracy: 0.7775 - val_loss: 0.7746 - val_accuracy: 0.6727
# Epoch 48/50
# 37/37 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.7307
# Epoch 48: val_accuracy did not improve from 0.74545
# 37/37 [==============================] - 23s 622ms/step - loss: 0.6257 - accuracy: 0.7307 - val_loss: 0.6643 - val_accuracy: 0.7273
# Epoch 49/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5601 - accuracy: 0.7827
# Epoch 49: val_accuracy did not improve from 0.74545
# 37/37 [==============================] - 24s 639ms/step - loss: 0.5601 - accuracy: 0.7827 - val_loss: 0.6590 - val_accuracy: 0.7273
# Epoch 50/50
# 37/37 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.7688
# Epoch 50: val_accuracy did not improve from 0.74545
# 37/37 [==============================] - 24s 639ms/step - loss: 0.5829 - accuracy: 0.7688 - val_loss: 0.7002 - val_accuracy: 0.6909

# %%
model.load_weights('/kaggle/working/model.h5')

# %%
# Plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, len(history.history["loss"])), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, len(history.history["val_loss"])), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, len(history.history["accuracy"])), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, len(history.history["val_accuracy"])), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("VGG_Model")

# %%
val_loss, val_accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", val_loss)
print("Test accuracy:", val_accuracy)

X = 32
img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = np.expand_dims(img_single, 0)

predictions_single = model.predict(img_single)
print('A.I predicts:', categories[np.argmax(predictions_single)])
print("Correct prediction for label", np.argmax(y_test[X]), 'is', categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()
# Out:
# Test loss: 0.6268224716186523
# Test accuracy: 0.739393949508667
# 1/1 [==============================] - 1s 675ms/step
# A.I predicts: 3Moderate
# Correct prediction for label 1 is 3Moderate

# %%
test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)

cm = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm, figsize=(12, 8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(len(categories)), categories, fontsize=12)
plt.yticks(range(len(categories)), categories, fontsize=12)
plt.show()
# Out:
# 11/11 [==============================] - 2s 151ms/step
