# %%
import cv2
import os
import numpy as np
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix
import matplotlib.pyplot as plt
from keras.applications.vgg16 import VGG16
from keras.optimizers import Adam
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %%
data_path = '/kaggle/input/koa-1500/MedicalExpert-I'
categories = os.listdir(data_path)
labels = [i for i in range(len(categories))]

label_dict = dict(zip(categories, labels))

img_size = 256
data = []
label = []

for category in categories:
    folder_path = os.path.join(data_path, category)
    img_names = os.listdir(folder_path)

    for img_name in img_names:
        img_path = os.path.join(folder_path, img_name)
        img = cv2.imread(img_path)
        try:
            gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            resized = cv2.resize(gray, (img_size, img_size))
            data.append(resized)
            label.append(label_dict[category])
        except Exception as e:
            print('Exception:', e)

# %%
data = np.array(data) / 255.0
data_rgb = np.repeat(data[..., np.newaxis], 3, -1)
label = np.array(label)
new_label = np_utils.to_categorical(label)

x_train, x_test, y_train, y_test = train_test_split(data_rgb, new_label, test_size=0.2, random_state=42)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.125, random_state=42)

datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True,
    vertical_flip=True
)

datagen.fit(x_train)

# %%
model = Sequential()
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

for layer in base_model.layers[:5]:
    layer.trainable = False

model.add(base_model)
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(categories), activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.0001), metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1024)              33555456
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 5)                 1285
#
# =================================================================
# Total params: 48,927,557
# Trainable params: 48,814,981
# Non-trainable params: 112,576
# _________________________________________________________________

# %%
checkpoint = ModelCheckpoint('/kaggle/working/model.h5', monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)
#early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1)
callbacks = [checkpoint]

history = model.fit(datagen.flow(x_train, y_train, batch_size=32),
                    epochs=80,
                    validation_data=(x_val, y_val),
                    callbacks=callbacks)
# Out:
# Epoch 1/80
# 37/37 [==============================] - ETA: 0s - loss: 1.6477 - accuracy: 0.2597
# Epoch 1: val_accuracy improved from -inf to 0.27273, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 45s 710ms/step - loss: 1.6477 - accuracy: 0.2597 - val_loss: 1.5680 - val_accuracy: 0.2727
# Epoch 2/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5628 - accuracy: 0.3065
# Epoch 2: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 21s 557ms/step - loss: 1.5628 - accuracy: 0.3065 - val_loss: 1.5584 - val_accuracy: 0.2727
# Epoch 3/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5596 - accuracy: 0.2840
# Epoch 3: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 21s 555ms/step - loss: 1.5596 - accuracy: 0.2840 - val_loss: 1.5544 - val_accuracy: 0.2727
# Epoch 4/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5371 - accuracy: 0.3134
# Epoch 4: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 22s 577ms/step - loss: 1.5371 - accuracy: 0.3134 - val_loss: 1.5543 - val_accuracy: 0.2727
# Epoch 5/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5459 - accuracy: 0.3074
# Epoch 5: val_accuracy did not improve from 0.27273
# 37/37 [==============================] - 22s 584ms/step - loss: 1.5459 - accuracy: 0.3074 - val_loss: 1.5543 - val_accuracy: 0.2727
# Epoch 6/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5487 - accuracy: 0.3065
# Epoch 6: val_accuracy improved from 0.27273 to 0.27879, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 23s 612ms/step - loss: 1.5487 - accuracy: 0.3065 - val_loss: 1.5466 - val_accuracy: 0.2788
# Epoch 7/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5279 - accuracy: 0.3126
# Epoch 7: val_accuracy did not improve from 0.27879
# 37/37 [==============================] - 22s 578ms/step - loss: 1.5279 - accuracy: 0.3126 - val_loss: 1.5578 - val_accuracy: 0.2727
# Epoch 8/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5303 - accuracy: 0.3281
# Epoch 8: val_accuracy did not improve from 0.27879
# 37/37 [==============================] - 21s 558ms/step - loss: 1.5303 - accuracy: 0.3281 - val_loss: 1.5617 - val_accuracy: 0.2727
# Epoch 9/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5316 - accuracy: 0.3238
# Epoch 9: val_accuracy improved from 0.27879 to 0.29697, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 23s 618ms/step - loss: 1.5316 - accuracy: 0.3238 - val_loss: 1.5692 - val_accuracy: 0.2970
# Epoch 10/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5243 - accuracy: 0.3177
# Epoch 10: val_accuracy did not improve from 0.29697
# 37/37 [==============================] - 22s 584ms/step - loss: 1.5243 - accuracy: 0.3177 - val_loss: 1.5261 - val_accuracy: 0.2727
# Epoch 11/80
# 37/37 [==============================] - ETA: 0s - loss: 1.5134 - accuracy: 0.3247
# Epoch 11: val_accuracy did not improve from 0.29697
# 37/37 [==============================] - 21s 562ms/step - loss: 1.5134 - accuracy: 0.3247 - val_loss: 1.5096 - val_accuracy: 0.2727
# Epoch 12/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4700 - accuracy: 0.3377
# Epoch 12: val_accuracy improved from 0.29697 to 0.33333, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 766ms/step - loss: 1.4700 - accuracy: 0.3377 - val_loss: 1.5131 - val_accuracy: 0.3333
# Epoch 13/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4513 - accuracy: 0.3403
# Epoch 13: val_accuracy did not improve from 0.33333
# 37/37 [==============================] - 22s 577ms/step - loss: 1.4513 - accuracy: 0.3403 - val_loss: 1.4567 - val_accuracy: 0.3273
# Epoch 14/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4586 - accuracy: 0.3351
# Epoch 14: val_accuracy did not improve from 0.33333
# 37/37 [==============================] - 20s 548ms/step - loss: 1.4586 - accuracy: 0.3351 - val_loss: 1.4579 - val_accuracy: 0.3333
# Epoch 15/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4798 - accuracy: 0.3403
# Epoch 15: val_accuracy improved from 0.33333 to 0.36970, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 758ms/step - loss: 1.4798 - accuracy: 0.3403 - val_loss: 1.5027 - val_accuracy: 0.3697
# Epoch 16/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4328 - accuracy: 0.3541
# Epoch 16: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 21s 572ms/step - loss: 1.4328 - accuracy: 0.3541 - val_loss: 1.4506 - val_accuracy: 0.3394
# Epoch 17/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4415 - accuracy: 0.3377
# Epoch 17: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 20s 548ms/step - loss: 1.4415 - accuracy: 0.3377 - val_loss: 1.4571 - val_accuracy: 0.3697
# Epoch 18/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4081 - accuracy: 0.3567
# Epoch 18: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 21s 565ms/step - loss: 1.4081 - accuracy: 0.3567 - val_loss: 1.4157 - val_accuracy: 0.3697
# Epoch 19/80
# 37/37 [==============================] - ETA: 0s - loss: 1.4466 - accuracy: 0.3463
# Epoch 19: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 21s 565ms/step - loss: 1.4466 - accuracy: 0.3463 - val_loss: 1.4310 - val_accuracy: 0.3455
# Epoch 20/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3989 - accuracy: 0.3740
# Epoch 20: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 22s 579ms/step - loss: 1.3989 - accuracy: 0.3740 - val_loss: 1.4153 - val_accuracy: 0.3455
# Epoch 21/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3950 - accuracy: 0.3697
# Epoch 21: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 21s 565ms/step - loss: 1.3950 - accuracy: 0.3697 - val_loss: 1.4077 - val_accuracy: 0.3576
# Epoch 22/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3957 - accuracy: 0.3662
# Epoch 22: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 21s 563ms/step - loss: 1.3957 - accuracy: 0.3662 - val_loss: 1.3855 - val_accuracy: 0.3697
# Epoch 23/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3799 - accuracy: 0.3645
# Epoch 23: val_accuracy did not improve from 0.36970
# 37/37 [==============================] - 22s 579ms/step - loss: 1.3799 - accuracy: 0.3645 - val_loss: 1.3939 - val_accuracy: 0.3697
# Epoch 24/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3763 - accuracy: 0.3610
# Epoch 24: val_accuracy improved from 0.36970 to 0.38182, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 752ms/step - loss: 1.3763 - accuracy: 0.3610 - val_loss: 1.3691 - val_accuracy: 0.3818
# Epoch 25/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3983 - accuracy: 0.3662
# Epoch 25: val_accuracy improved from 0.38182 to 0.41818, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 26s 693ms/step - loss: 1.3983 - accuracy: 0.3662 - val_loss: 1.4166 - val_accuracy: 0.4182
# Epoch 26/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3796 - accuracy: 0.3827
# Epoch 26: val_accuracy did not improve from 0.41818
# 37/37 [==============================] - 21s 562ms/step - loss: 1.3796 - accuracy: 0.3827 - val_loss: 1.4344 - val_accuracy: 0.3636
# Epoch 27/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3616 - accuracy: 0.3732
# Epoch 27: val_accuracy did not improve from 0.41818
# 37/37 [==============================] - 21s 560ms/step - loss: 1.3616 - accuracy: 0.3732 - val_loss: 1.3561 - val_accuracy: 0.3758
# Epoch 28/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3696 - accuracy: 0.3593
# Epoch 28: val_accuracy improved from 0.41818 to 0.44848, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 761ms/step - loss: 1.3696 - accuracy: 0.3593 - val_loss: 1.3260 - val_accuracy: 0.4485
# Epoch 29/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3567 - accuracy: 0.3766
# Epoch 29: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 21s 566ms/step - loss: 1.3567 - accuracy: 0.3766 - val_loss: 1.3755 - val_accuracy: 0.3273
# Epoch 30/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3354 - accuracy: 0.4087
# Epoch 30: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 21s 558ms/step - loss: 1.3354 - accuracy: 0.4087 - val_loss: 1.3849 - val_accuracy: 0.4121
# Epoch 31/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3439 - accuracy: 0.3879
# Epoch 31: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 21s 559ms/step - loss: 1.3439 - accuracy: 0.3879 - val_loss: 1.3804 - val_accuracy: 0.4061
# Epoch 32/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3347 - accuracy: 0.3974
# Epoch 32: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 20s 541ms/step - loss: 1.3347 - accuracy: 0.3974 - val_loss: 1.3916 - val_accuracy: 0.3818
# Epoch 33/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3180 - accuracy: 0.4199
# Epoch 33: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 21s 571ms/step - loss: 1.3180 - accuracy: 0.4199 - val_loss: 1.3233 - val_accuracy: 0.4424
# Epoch 34/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2595 - accuracy: 0.4649
# Epoch 34: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 20s 546ms/step - loss: 1.2595 - accuracy: 0.4649 - val_loss: 1.2641 - val_accuracy: 0.4303
# Epoch 35/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2817 - accuracy: 0.4208
# Epoch 35: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 22s 581ms/step - loss: 1.2817 - accuracy: 0.4208 - val_loss: 1.2807 - val_accuracy: 0.4424
# Epoch 36/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3112 - accuracy: 0.3957
# Epoch 36: val_accuracy did not improve from 0.44848
# 37/37 [==============================] - 21s 568ms/step - loss: 1.3112 - accuracy: 0.3957 - val_loss: 1.3193 - val_accuracy: 0.4303
# Epoch 37/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2988 - accuracy: 0.4294
# Epoch 37: val_accuracy improved from 0.44848 to 0.45455, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 753ms/step - loss: 1.2988 - accuracy: 0.4294 - val_loss: 1.2621 - val_accuracy: 0.4545
# Epoch 38/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2589 - accuracy: 0.4494
# Epoch 38: val_accuracy did not improve from 0.45455
# 37/37 [==============================] - 20s 547ms/step - loss: 1.2589 - accuracy: 0.4494 - val_loss: 1.3519 - val_accuracy: 0.3758
# Epoch 39/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2776 - accuracy: 0.4407
# Epoch 39: val_accuracy did not improve from 0.45455
# 37/37 [==============================] - 21s 565ms/step - loss: 1.2776 - accuracy: 0.4407 - val_loss: 1.2426 - val_accuracy: 0.4485
# Epoch 40/80
# 37/37 [==============================] - ETA: 0s - loss: 1.3113 - accuracy: 0.4216
# Epoch 40: val_accuracy did not improve from 0.45455
# 37/37 [==============================] - 21s 570ms/step - loss: 1.3113 - accuracy: 0.4216 - val_loss: 1.2893 - val_accuracy: 0.4303
# Epoch 41/80
# 37/37 [==============================] - ETA: 0s - loss: 1.2459 - accuracy: 0.4519
# Epoch 41: val_accuracy did not improve from 0.45455
# 37/37 [==============================] - 21s 564ms/step - loss: 1.2459 - accuracy: 0.4519 - val_loss: 1.2800 - val_accuracy: 0.4242
# Epoch 42/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1912 - accuracy: 0.4494
# Epoch 42: val_accuracy did not improve from 0.45455
# 37/37 [==============================] - 21s 590ms/step - loss: 1.1912 - accuracy: 0.4494 - val_loss: 1.2257 - val_accuracy: 0.4424
# Epoch 43/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1747 - accuracy: 0.4814
# Epoch 43: val_accuracy improved from 0.45455 to 0.47879, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 763ms/step - loss: 1.1747 - accuracy: 0.4814 - val_loss: 1.1755 - val_accuracy: 0.4788
# Epoch 44/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1754 - accuracy: 0.4771
# Epoch 44: val_accuracy improved from 0.47879 to 0.49697, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 26s 702ms/step - loss: 1.1754 - accuracy: 0.4771 - val_loss: 1.1650 - val_accuracy: 0.4970
# Epoch 45/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1977 - accuracy: 0.4874
# Epoch 45: val_accuracy did not improve from 0.49697
# 37/37 [==============================] - 21s 566ms/step - loss: 1.1977 - accuracy: 0.4874 - val_loss: 1.1516 - val_accuracy: 0.4667
# Epoch 46/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1174 - accuracy: 0.5255
# Epoch 46: val_accuracy did not improve from 0.49697
# 37/37 [==============================] - 20s 543ms/step - loss: 1.1174 - accuracy: 0.5255 - val_loss: 1.1172 - val_accuracy: 0.4970
# Epoch 47/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0928 - accuracy: 0.5100
# Epoch 47: val_accuracy did not improve from 0.49697
# 37/37 [==============================] - 21s 559ms/step - loss: 1.0928 - accuracy: 0.5100 - val_loss: 1.1942 - val_accuracy: 0.4545
# Epoch 48/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1523 - accuracy: 0.4840
# Epoch 48: val_accuracy improved from 0.49697 to 0.50303, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 750ms/step - loss: 1.1523 - accuracy: 0.4840 - val_loss: 1.2078 - val_accuracy: 0.5030
# Epoch 49/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1079 - accuracy: 0.5143
# Epoch 49: val_accuracy did not improve from 0.50303
# 37/37 [==============================] - 21s 561ms/step - loss: 1.1079 - accuracy: 0.5143 - val_loss: 1.1420 - val_accuracy: 0.4364
# Epoch 50/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0519 - accuracy: 0.5342
# Epoch 50: val_accuracy did not improve from 0.50303
# 37/37 [==============================] - 21s 574ms/step - loss: 1.0519 - accuracy: 0.5342 - val_loss: 1.0722 - val_accuracy: 0.5030
# Epoch 51/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0393 - accuracy: 0.5351
# Epoch 51: val_accuracy did not improve from 0.50303
# 37/37 [==============================] - 21s 562ms/step - loss: 1.0393 - accuracy: 0.5351 - val_loss: 1.5983 - val_accuracy: 0.3091
# Epoch 52/80
# 37/37 [==============================] - ETA: 0s - loss: 1.1508 - accuracy: 0.4874
# Epoch 52: val_accuracy did not improve from 0.50303
# 37/37 [==============================] - 21s 575ms/step - loss: 1.1508 - accuracy: 0.4874 - val_loss: 1.1434 - val_accuracy: 0.4424
# Epoch 53/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0368 - accuracy: 0.5489
# Epoch 53: val_accuracy improved from 0.50303 to 0.55758, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 752ms/step - loss: 1.0368 - accuracy: 0.5489 - val_loss: 0.9773 - val_accuracy: 0.5576
# Epoch 54/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9579 - accuracy: 0.5801
# Epoch 54: val_accuracy improved from 0.55758 to 0.57576, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 745ms/step - loss: 0.9579 - accuracy: 0.5801 - val_loss: 0.9646 - val_accuracy: 0.5758
# Epoch 55/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0137 - accuracy: 0.5576
# Epoch 55: val_accuracy improved from 0.57576 to 0.58182, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 760ms/step - loss: 1.0137 - accuracy: 0.5576 - val_loss: 0.9747 - val_accuracy: 0.5818
# Epoch 56/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9664 - accuracy: 0.5879
# Epoch 56: val_accuracy did not improve from 0.58182
# 37/37 [==============================] - 21s 569ms/step - loss: 0.9664 - accuracy: 0.5879 - val_loss: 0.9598 - val_accuracy: 0.5697
# Epoch 57/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9680 - accuracy: 0.5636
# Epoch 57: val_accuracy improved from 0.58182 to 0.60000, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 27s 728ms/step - loss: 0.9680 - accuracy: 0.5636 - val_loss: 0.9248 - val_accuracy: 0.6000
# Epoch 58/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9361 - accuracy: 0.6026
# Epoch 58: val_accuracy did not improve from 0.60000
# 37/37 [==============================] - 20s 544ms/step - loss: 0.9361 - accuracy: 0.6026 - val_loss: 0.9089 - val_accuracy: 0.5697
# Epoch 59/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9049 - accuracy: 0.6035
# Epoch 59: val_accuracy improved from 0.60000 to 0.62424, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 760ms/step - loss: 0.9049 - accuracy: 0.6035 - val_loss: 0.8913 - val_accuracy: 0.6242
# Epoch 60/80
# 37/37 [==============================] - ETA: 0s - loss: 1.0115 - accuracy: 0.5524
# Epoch 60: val_accuracy did not improve from 0.62424
# 37/37 [==============================] - 21s 560ms/step - loss: 1.0115 - accuracy: 0.5524 - val_loss: 0.9823 - val_accuracy: 0.6242
# Epoch 61/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9396 - accuracy: 0.6121
# Epoch 61: val_accuracy improved from 0.62424 to 0.63636, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 27s 729ms/step - loss: 0.9396 - accuracy: 0.6121 - val_loss: 0.8727 - val_accuracy: 0.6364
# Epoch 62/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9414 - accuracy: 0.5879
# Epoch 62: val_accuracy did not improve from 0.63636
# 37/37 [==============================] - 21s 551ms/step - loss: 0.9414 - accuracy: 0.5879 - val_loss: 1.0196 - val_accuracy: 0.5333
# Epoch 63/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8997 - accuracy: 0.6286
# Epoch 63: val_accuracy improved from 0.63636 to 0.69091, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 772ms/step - loss: 0.8997 - accuracy: 0.6286 - val_loss: 0.8491 - val_accuracy: 0.6909
# Epoch 64/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8737 - accuracy: 0.6312
# Epoch 64: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 566ms/step - loss: 0.8737 - accuracy: 0.6312 - val_loss: 0.8700 - val_accuracy: 0.6182
# Epoch 65/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8289 - accuracy: 0.6407
# Epoch 65: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 562ms/step - loss: 0.8289 - accuracy: 0.6407 - val_loss: 0.9469 - val_accuracy: 0.6000
# Epoch 66/80
# 37/37 [==============================] - ETA: 0s - loss: 0.9170 - accuracy: 0.6190
# Epoch 66: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 555ms/step - loss: 0.9170 - accuracy: 0.6190 - val_loss: 0.8366 - val_accuracy: 0.6909
# Epoch 67/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8657 - accuracy: 0.6494
# Epoch 67: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 564ms/step - loss: 0.8657 - accuracy: 0.6494 - val_loss: 0.9217 - val_accuracy: 0.6242
# Epoch 68/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8099 - accuracy: 0.6675
# Epoch 68: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 556ms/step - loss: 0.8099 - accuracy: 0.6675 - val_loss: 0.8022 - val_accuracy: 0.6545
# Epoch 69/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8192 - accuracy: 0.6779
# Epoch 69: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 544ms/step - loss: 0.8192 - accuracy: 0.6779 - val_loss: 0.8013 - val_accuracy: 0.6545
# Epoch 70/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8391 - accuracy: 0.6571
# Epoch 70: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 20s 545ms/step - loss: 0.8391 - accuracy: 0.6571 - val_loss: 0.7982 - val_accuracy: 0.6909
# Epoch 71/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7829 - accuracy: 0.6952
# Epoch 71: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 564ms/step - loss: 0.7829 - accuracy: 0.6952 - val_loss: 0.7935 - val_accuracy: 0.6545
# Epoch 72/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7900 - accuracy: 0.6797
# Epoch 72: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 20s 546ms/step - loss: 0.7900 - accuracy: 0.6797 - val_loss: 0.8080 - val_accuracy: 0.6545
# Epoch 73/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7696 - accuracy: 0.6926
# Epoch 73: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 569ms/step - loss: 0.7696 - accuracy: 0.6926 - val_loss: 0.8228 - val_accuracy: 0.6606
# Epoch 74/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7770 - accuracy: 0.6788
# Epoch 74: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 22s 579ms/step - loss: 0.7770 - accuracy: 0.6788 - val_loss: 0.8395 - val_accuracy: 0.6303
# Epoch 75/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7579 - accuracy: 0.7004
# Epoch 75: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 21s 549ms/step - loss: 0.7579 - accuracy: 0.7004 - val_loss: 0.8287 - val_accuracy: 0.6485
# Epoch 76/80
# 37/37 [==============================] - ETA: 0s - loss: 0.8408 - accuracy: 0.6597
# Epoch 76: val_accuracy did not improve from 0.69091
# 37/37 [==============================] - 22s 591ms/step - loss: 0.8408 - accuracy: 0.6597 - val_loss: 0.8101 - val_accuracy: 0.6485
# Epoch 77/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7386 - accuracy: 0.7039
# Epoch 77: val_accuracy improved from 0.69091 to 0.69697, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 28s 759ms/step - loss: 0.7386 - accuracy: 0.7039 - val_loss: 0.7615 - val_accuracy: 0.6970
# Epoch 78/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7371 - accuracy: 0.6987
# Epoch 78: val_accuracy improved from 0.69697 to 0.70303, saving model to /kaggle/working/model.h5
# 37/37 [==============================] - 27s 716ms/step - loss: 0.7371 - accuracy: 0.6987 - val_loss: 0.7541 - val_accuracy: 0.7030
# Epoch 79/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7498 - accuracy: 0.7022
# Epoch 79: val_accuracy did not improve from 0.70303
# 37/37 [==============================] - 21s 563ms/step - loss: 0.7498 - accuracy: 0.7022 - val_loss: 0.7808 - val_accuracy: 0.6485
# Epoch 80/80
# 37/37 [==============================] - ETA: 0s - loss: 0.7200 - accuracy: 0.7074
# Epoch 80: val_accuracy did not improve from 0.70303
# 37/37 [==============================] - 22s 581ms/step - loss: 0.7200 - accuracy: 0.7074 - val_loss: 1.0388 - val_accuracy: 0.5939

# %%
model.load_weights('/kaggle/working/model.h5')

# %%
# Plot the training loss and accuracy
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, len(history.history["loss"])), history.history["loss"], label="train_loss")
plt.plot(np.arange(0, len(history.history["val_loss"])), history.history["val_loss"], label="val_loss")
plt.plot(np.arange(0, len(history.history["accuracy"])), history.history["accuracy"], label="train_acc")
plt.plot(np.arange(0, len(history.history["val_accuracy"])), history.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="center right")
plt.savefig("vgg_Model")

# %%
val_loss, val_accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", val_loss)
print("Test accuracy:", val_accuracy)

X = 32
img_single = x_test[X]
img_single = cv2.resize(img_single, (img_size, img_size))
img_single = np.expand_dims(img_single, 0)

predictions_single = model.predict(img_single)
print('A.I predicts:', categories[np.argmax(predictions_single)])
print("Correct prediction for label", np.argmax(y_test[X]), 'is', categories[np.argmax(y_test[X])])
plt.imshow(np.squeeze(img_single))
plt.grid(False)
plt.show()

test_labels = np.argmax(y_test, axis=1)
predictions = model.predict(x_test)
predictions = np.argmax(predictions, axis=-1)

cm = confusion_matrix(test_labels, predictions)
plt.figure()
plot_confusion_matrix(cm, figsize=(12, 8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(len(categories)), categories, fontsize=12)
plt.yticks(range(len(categories)), categories, fontsize=12)
plt.show()
# Out:
# Test loss: 0.8367896676063538
# Test accuracy: 0.678787887096405
# 1/1 [==============================] - 1s 682ms/step
# A.I predicts: 4Severe
# Correct prediction for label 1 is 3Moderate
# 11/11 [==============================] - 1s 140ms/step
